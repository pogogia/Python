# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset('iris')

# %%
plt.rcParams["patch.force_edgecolor"] = True

# %%
tips = sns.load_dataset('tips')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %% [markdown]
# ## A) Distribution Plots

# %% [markdown]
# ## i) Disjoint Plot

# %%
sns.distplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'], kde = False)

# %%
sns.distplot(tips['total_bill'], kde = False, bins=30)

# %% [markdown]
# ## ii) Joint Plot

# %%
#by default kind is SCATTER plot.
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='resid')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %% [markdown]
# ## iii) Pair Plot

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='smoker')

# %%
sns.pairplot(tips,hue='smoker',palette= 'coolwarm')

# %% [markdown]
# ## iv) Rug Plot

# %%
sns.rugplot(tips['total_bill'])

# %% [markdown]
# ## B) Categorical plots

# %% [markdown]
# ## i) Bar Plot

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='tip',data=tips)

# %%
sns.barplot(x='sex',y='tip',data=tips,estimator=np.std)

# %%
sns.barplot(x='sex',y='tip',data=tips,estimator=np.std,hue='smoker')

# %% [markdown]
# # iii) Count Plot

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.countplot(x='smoker',data=tips)

# %%
sns.countplot(x='smoker',data=tips,hue='sex')

# %% [markdown]
# # iii) Box Plot

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='sex')

# %% [markdown]
# ## iv) Violin Plot

# %%
sns.violinplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex')

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)

# %% [markdown]
# ## v) Strip Plot

# %%
sns.stripplot(x='day',y='total_bill',data=tips)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True)

# %% [markdown]
# ## vi) Swarm Plot

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='white')

# %% [markdown]
# ## vii) Factor Plot

# %%
# factor plot is nothing but generalized fnction for categorical plots with attribute kind. 
# in kind we specify the type of plot we want.

sns.factorplot(x='day',y='total_bill',data=tips,kind='bar')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='box')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day',data=tips,kind='count')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='violin')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='swarm',jitter=True)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-959cd3bb362c> in <module>
# ----> 1 sns.factorplot(x='day',y='total_bill',data=tips,kind='swarm',jitter=True)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in factorplot(*args, **kwargs)
#    3674     kwargs.setdefault("kind", "point")
#    3675
# -> 3676     return catplot(*args, **kwargs)
#    3677
#    3678
#
# ...

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='strip')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ## C) Matrix Plots

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
flights = sns.load_dataset('flights')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %% [markdown]
# ## i) Heat Map

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tp = tips.pivot_table(index='total_bill',columns='sex',values='tip')

# %%
tp
# Out:
# sex          Male  Female
# total_bill
# 3.07          NaN   1.000
# 5.75          NaN   1.000
# 7.25         5.15   1.000
# 7.51         2.00     NaN
# 7.56         1.44     NaN
# 7.74         1.44     NaN
# 8.35          NaN   1.500
# 8.51          NaN   1.250
# 8.52         1.48     NaN
# 8.58         1.92     NaN
# 8.77         2.00     NaN
# 9.55         1.45     NaN
# 9.60          NaN   4.000
# 9.68         1.32     NaN
# 9.78         1.73     NaN
# 9.94         1.56     NaN
# 10.07        1.25   1.830
# 10.09         NaN   2.000
# 10.27        1.71     NaN
# 10.29         NaN   2.600
# 10.33         NaN   1.835
# 10.34        1.83     NaN
# 10.51        1.25     NaN
# 10.59         NaN   1.610
# 10.63         NaN   2.000
# 10.65         NaN   1.500
# 10.77        1.47     NaN
# 11.02        1.98     NaN
# 11.17         NaN   1.500
# 11.24        1.76     NaN
# ...           ...     ...
# 30.40        5.60     NaN
# 30.46        2.00     NaN
# 31.27        5.00     NaN
# ...

# %%
sns.heatmap(tp)

# %%
tc = tips.corr()

# %%
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc,annot=True)

# %%
sns.heatmap(tc,annot=True,cmap='coolwarm')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flt = flights.pivot_table(index='month',columns='year',values='passengers')

# %%
flt
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(flt)

# %%
sns.heatmap(flt,cmap='coolwarm',linewidths=1,linecolor='black')

# %% [markdown]
# ## ii) Cluster Map

# %%
sns.heatmap(flt,cmap='coolwarm')

# %%
sns.clustermap(flt,cmap='coolwarm')

# %%
sns.clustermap(flt,cmap='coolwarm', standard_scale=1)

# %% [markdown]
# ## D) Grids

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %% [markdown]
# ## i) Pair Grid

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_upper(sns.kdeplot)
g.map_lower(plt.scatter)

# %% [markdown]
# ## ii) Facet Grid

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['petal_width'].unique()
# Out:
# array([0.2, 0.4, 0.3, 0.1, 0.5, 0.6, 1.4, 1.5, 1.3, 1.6, 1. , 1.1, 1.8,
#        1.2, 1.7, 2.5, 1.9, 2.1, 2.2, 2. , 2.4, 2.3])

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
g = sns.FacetGrid(data=tips,col='sex',row='smoker',hue='time')
g.map(plt.scatter,'total_bill','tip').add_legend()

# %% [markdown]
# ## iii) Joint Grid

# %%
g = sns.JointGrid(x='total_bill',y='tip',data=tips)
g.plot(plt.scatter,sns.distplot)

# %% [markdown]
# ## E) Regression Plot

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='magma',markers=['o','v'],scatter_kws={'s':50})

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='magma',markers=['o','v'],scatter_kws={'s':50},col='day',row='smoker')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='magma',markers=['o','v'],scatter_kws={'s':50},col='time',row='smoker')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='magma',markers=['o','v'],scatter_kws={'s':50},col='time',row='smoker',aspect=0.6,size=8)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Styling and Colouring

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot('sex',data=tips)

# %%
sns.set_style('darkgrid')
sns.countplot('sex',data=tips)

# %%
sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
sns.countplot('sex',data=tips)

# %%
sns.countplot('sex',data=tips)
sns.despine()

# %%
sns.countplot('sex',data=tips)
sns.despine(left=True,bottom=True)

# %%
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(12,6))
sns.countplot('sex',data=tips)

# %%
sns.set_context('notebook',font_scale=1.5)
sns.countplot('sex',data=tips)

# %% [markdown]
# ## Colouring

# %% [markdown]
# ## get names of palette from matplotlib colormap website

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='pastel')
