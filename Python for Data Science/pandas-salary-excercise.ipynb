# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\User\\python for data science'

# %%
pd.read_csv('C:\\Users\\User\\python for data science\\Refactored_Py_DS_ML_Bootcamp-master\\03-Python-for-Data-Analysis-Pandas\\example')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_csv('C:\\Users\\User\\python for data science\\Refactored_Py_DS_ML_Bootcamp-master\\03-Python-for-Data-Analysis-Pandas\\example')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('output',index=False)

# %%
pd.read_csv('output')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df_excel = pd.read_excel('C:\\Users\\User\\python for data science\\Refactored_Py_DS_ML_Bootcamp-master\\03-Python-for-Data-Analysis-Pandas\\Excel_Sample.xlsx')

# %%
df_excel
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df_excel.to_excel('Excel_output.xlsx',sheet_name='NewSheet')

# %%
pd.read_excel('Excel_output.xlsx',sheet_name='NewSheet')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df_html = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df_html
# Out:
# [                                             Bank Name                City  \
#  0                                 The Enloe State Bank              Cooper
#  1                  Washington Federal Bank for Savings             Chicago
#  2      The Farmers and Merchants State Bank of Argonia             Argonia
#  3                                  Fayette County Bank          Saint Elmo
#  4    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
#  5                                       First NBC Bank         New Orleans
#  6                                        Proficio Bank  Cottonwood Heights
#  7                        Seaway Bank and Trust Company             Chicago
#  8                               Harvest Community Bank          Pennsville
#  9                                          Allied Bank            Mulberry
#  10                        The Woodbury Banking Company            Woodbury
# ...

# %%
df_html[0]
# Out:
#                                              Bank Name                City  \
# 0                                 The Enloe State Bank              Cooper
# 1                  Washington Federal Bank for Savings             Chicago
# 2      The Farmers and Merchants State Bank of Argonia             Argonia
# 3                                  Fayette County Bank          Saint Elmo
# 4    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 5                                       First NBC Bank         New Orleans
# 6                                        Proficio Bank  Cottonwood Heights
# 7                        Seaway Bank and Trust Company             Chicago
# 8                               Harvest Community Bank          Pennsville
# 9                                          Allied Bank            Mulberry
# 10                        The Woodbury Banking Company            Woodbury
# ...

# %%
sal = pd.read_csv('C:\\Users\\User\\python for data science\\Refactored_Py_DS_ML_Bootcamp-master\\04-Pandas-Exercises\\Salaries.csv')

# %%
sal
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %%
sal[(sal['EmployeeName'] == 'JOSEPH DRISCOLL')]['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
sal[sal['TotalPayBenefits']== sal['TotalPayBenefits'].max()] #['EmployeeName']
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
sal
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
sal.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
sum(sal[sal['Year']==2013]['JobTitle'].value_counts()  ==1)
# Out:
# 202

# %%
sal[sal['JobTitle'].str.match('Chief')].count
# Out:
# <bound method DataFrame.count of             Id          EmployeeName                        JobTitle  \
# 36160    36161          Gregory Suhr                 Chief of Police
# 36162    36163    Joanne Hayes-White          Chief, Fire Department
# 36345    36346       Burk Delventhal  Chief Atty1 (Civil & Criminal)
# 36419    36420         Joanne Hoeper  Chief Atty1 (Civil & Criminal)
# 36420    36421           Wendy Still   Chief Adult Probation Officer
# 36817    36818           Freya Horne  Chief Atty1 (Civil & Criminal)
# 36881    36882      Matthew Gonzalez  Chief Atty1 (Civil & Criminal)
# 36888    36889        James Harrigan  Chief Atty1 (Civil & Criminal)
# 37011    37012      Albert Waters II            Chief Deputy Sheriff
# 37433    37434       Matthew Freeman            Chief Deputy Sheriff
# 37701    37702         Perry Bonelli       Chief Stationary Engineer
# 38099    38100     Katherine Johnson            Chief Deputy Sheriff
# ...

# %%
def chief_string(title):
    if 'chief' in title.lower():
        return True
    else:
        return False

# %%
sum(sal['JobTitle'].apply(lambda x: chief_string(x)))
# Out:
# 627

# %%
sal[sal['TotalPayBenefits']== sal['TotalPayBenefits'].max()] #['EmployeeName']
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
sal[sal['TotalPayBenefits']== sal['TotalPayBenefits'].min()] #['EmployeeName']
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
pwd
# Out:
# 'C:\\Users\\User\\python for data science'
